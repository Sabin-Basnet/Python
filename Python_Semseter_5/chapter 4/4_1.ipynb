# %%
import pandas as pd
import numpy as np

# %%
X = np.random.random(20000)
df = pd.DataFrame({"X":X})
print("Kurtosis of X column ", df['X'].kurt())
# Out:
# Kurtosis of X column  -1.192609221595625
