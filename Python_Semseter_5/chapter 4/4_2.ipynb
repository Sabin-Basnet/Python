# %%
from scipy.stats import chi2_contingency

# %%
chi2, p, dof,exp = chi2_contingency(observed, correction=False)

print(f"Chi-square: {chi2:.4f}")
print(f"P-value: {p:.6f}")
print(f"Degree of Freedom: {dof}")
print(f"Expected-Value: {exp}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 chi2, p, dof,exp = chi2_contingency(observed, correction=False)
#       3 print(f"Chi-square: {chi2:.4f}")
#       4 print(f"P-value: {p:.6f}")
#
# NameError: name 'observed' is not defined
