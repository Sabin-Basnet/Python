# %%
class Animal:
    def __init__(self,name):
        self.name= name

    def speak(self):
        print(f"{self.name} Speaks")

class Dog(Animal):
    def __init__(self, name,breed):
        super().__init__(name)
        self.breed=breed
    
    def speak(self):
        super().speak()
        print(f"{self.name} Barks")

d1=Dog("abc","xyz")
d1.speak()

# a1=Animal("yyy")
# a1.speak()
# Out:
# abc Speaks
# abc Barks

# %%
class A:
    def show(self):
        print("A")

class B:
    def show(self):
        print("B")

class C(A,B):
    pass

c1=C()
c1.show()
#gives priority to the first class
C.mro()
# Out:
# A
# [__main__.C, __main__.A, __main__.B, object]

# %%
# multi-level inheritance
class A:
    def show(self):
        print("A")

class B(A):
    def show(self):
        super().show()
        print("B")

class C(B):
    def show(self):
        super().show()
        print("C")

c1=C()
c1.show()
# Out:
# B
# A
# C
