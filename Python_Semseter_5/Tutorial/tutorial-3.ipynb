# %%
class Car:
    def __init__(self, make, model, year):
        self.make= make
        self.model = model
        self.year = year
    
    def display(self):
        print(f"Car is {self.make} make , model: {self.model} which is made in {self.year}")

    
c_obj = Car("BMW", "20F", "2000")
c_obj.display()
# Out:
# Car is BMW make , model: 20F which is made in 2000

# %%
class ElectricCar(Car):
    def __init__(self, make, model, year, batteryCapacity):
        super().__init__(make,model, year)
        self.batteryCapacity =batteryCapacity

    def battery_info(self):
        print(f"Battery Capacity: {self.batteryCapacity}")

    
ev1= ElectricCar("Tesla",'hybrid','2000','50K Mah')
ev1.display()
ev1.battery_info()
# Out:
# Car is Tesla make , model: hybrid which is made in 2000
# Battery Capacity: 50K Mah

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        print(f"Area : {self.length*self.width}")

    def perimeter(self):
        p = 2*(self.length + self.width)
        print(f"Perimeter: {p}")

R1= Rectangle(10,15)
R1.perimeter() 
R1.area()
# Out:
# Perimeter: 50
# Area : 150

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius

    def set_radius(self, radius):
        self._radius = radius

    def get_radius(self, radius):
        return self._radius
    
    def area(self):
        return 3.14 * (self._radius)**2
    
c1= Circle(7)
print(f"The radius of circle is {c1.area()}")
# Out:
# The radius of circle is 153.86

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        print(f"Successully deposited Rs.{amount}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"Successully deposited Rs.{amount}")


    def display_balance(self):
        print(f"Current balance: Rs.{self.balance}")

account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
account.display_balance()
# Out:
# Successully deposited Rs.500
# Successully deposited Rs.200
# Current balance: Rs.1300

# %%
# data from csv file

import pandas as pd

df = pd.read_csv("data.csv")
df
# Out:
#    Id Name
# 0   1  Abc
# 1   2  bcd

# %%
# data from excel file
