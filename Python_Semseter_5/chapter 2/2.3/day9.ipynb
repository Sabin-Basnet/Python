# %%
import requests
url="https://jsonplaceholder.typicode.com/posts"
payload = {"title":"Test", "body":"Hello API", "userID":1}
response = requests.post(url, json=payload)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\SABIN\anaconda3\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\SABIN\anaconda3\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
# SOAP API --> simple object access protocol
# uses XML for requests and responses
# !pip install zeep

# %%
from zeep import Client
# WSDL URL
wsdl="http://www.dneonline.com/calculator.asmx?WSDL"
client = Client(wsdl=wsdl)

# call a SOAP method
result = client.service.Add(10, 20)
print(result)
# Out:
# 30

# %%
import requests
from pprint import pprint
api_key="1e679f6aa64bfb3ba0eabd0dff937661"
city="Dharan"
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

response = requests.get(url)
print(response)
if response.status_code == 200:
    data = response.json()
    pprint(data)
else: 
    print(response.status_code)
# Out:
# <Response [200]>
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 26.8125, 'lon': 87.2835},
#  'dt': 1767248557,
#  'id': 1283460,
#  'main': {'feels_like': 18.84,
#           'grnd_level': 967,
#           'humidity': 54,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 19.43,
#           'temp_max': 19.43,
#           'temp_min': 19.43},
#  'name': 'Dharān',
#  'sys': {'country': 'NP', 'sunrise': 1767229174, 'sunset': 1767266915},
#  'timezone': 20700,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 199, 'gust': 1.81, 'speed': 2.31}}

# %%
import pandas as pd
from pandas import json_normalize

df=json_normalize(data)
# print(df.head())

df_weather= df[[
    'name',
    'main.temp',
    'main.humidity',
    'main.feels_like',
    'wind.speed',
    'weather'
]].copy()

df_weather['Description'] = df['weather'].apply(lambda x:x[0]['description'])
df_weather= df_weather.drop(columns=['weather'])

print(df_weather)
# Out:
#      name  main.temp  main.humidity  main.feels_like  wind.speed Description
# 0  Dharān      19.43             54            18.84        2.31   clear sky

# %%
import requests
from pprint import pprint
api_key="1e679f6aa64bfb3ba0eabd0dff937661"
city=["Dharan","Biratnagar","Pokhara","Ramechhap","Kathmandu"]
data=[]
df_list=[]

for c_name in city:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={c_name}&appid={api_key}&units=metric"
    response = requests.get(url)
    print(response)
    if response.status_code == 200:
        data = response.json()
        # pprint(data)
        df=json_normalize(data)
    print(df.head())

    df_weather= df[[
        'name',
        'main.temp',
        'main.humidity',
        'main.feels_like',
        'wind.speed',
        'weather'
    ]].copy()

    df_weather['Description'] = df['weather'].apply(lambda x:x[0]['description'])
    df_weather= df_weather.drop(columns=['weather'])

# print(df_weather)
df_list.append(df_weather)
# df_new= df_new.concat(df_list)
print(df_list)
# Out:
# <Response [200]>
#                                              weather  ...  sys.sunset
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  ...  1767266915
#
# [1 rows x 25 columns]
# <Response [200]>
#                                              weather  ...  sys.sunset
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  ...  1767266958
#
# [1 rows x 25 columns]
# <Response [200]>
#                                              weather  ...  sys.sunset
# 0  [{'id': 801, 'main': 'Clouds', 'description': ...  ...  1767267523
#
# [1 rows x 25 columns]
# <Response [200]>
#                                              weather  ...  sys.sunset
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  ...  1767267136
#
# [1 rows x 25 columns]
# <Response [200]>
#                                              weather  ...  sys.sunset
# 0  [{'id': 721, 'main': 'Haze', 'description': 'h...  ...  1767267271
#
# [1 rows x 26 columns]
# ...

# %%
# beautiful soup
