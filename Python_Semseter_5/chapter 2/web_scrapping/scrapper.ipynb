# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.onlinekhabar.com"

response = requests.get(url)
if response.status_code == 200:
    print("Successfully accessed the website.")
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Successfully accessed the website.

# %%
soup = BeautifulSoup(response.text, "html.parser")

headlines = soup.find_all("h2")

print("Top News Headlines:\n")

count = 1
for headline in headlines:
    text = headline.get_text(strip=True)
    if text:
        print(f"{count}. {text}")
        count += 1
    if count > 10:
        break
# Out:
# Top News Headlines:
#
# 1. ट्रेन्डिङ+
# 2. ताजा अपडेट+
# 3. महिला सौन्दर्य : अनावश्यक रौं हटाउन सेभिङ कति भरपर्दो ?
# 4. झन्डा बाँधेर देखाइने देशप्रेम
# 5. एकभन्दा बढी बैंक खाता राख्नु सही हो कि गलत ?
# 6. लैंगिक विभेदविरुद्ध उभिएकी रखाल अब राष्ट्रिय सभामा
# 7. बङ्गलादेशमा १० लाख जागिर गुम्ने खतरा, कपडा उद्योग बन्द गर्ने चेतावनी
# 8. फिनिस वैज्ञानिकको चमत्कार, तारबिनै हावामा दौडियो बिजुली
# 9. सापकोटाको ‘यात्राको लय’ सार्वजनिक
# 10. बाबुरामलाई प्रश्न : उम्मेदवारी छाड्नुभयो, अब कसलाई सघाउने ?

# %% [markdown]
# with links

# %%
soup = BeautifulSoup(response.text, "html.parser")

headlines = soup.find_all("h2")

print("Top News Headlines:\n")

count = 1
for headline in headlines:
    a_tag = headline.find("a")
    if a_tag:
        title = a_tag.get_text(strip=True)
        link = a_tag.get("href")

        # Some links are relative, make them full URL
        if link and link.startswith("/"):
            link = url + link

        if title and link:  
            print(f"{count}. {title}")
            print(f"   🔗 {link}\n")
            count += 1
    if count > 10:
        break
# Out:
# Top News Headlines:
#
# 1. नेपालमा रणनीतिक मतदान किन जरूरी छ ?
#    🔗 https://www.onlinekhabar.com/2026/01/1857278/why-is-strategic-voting-important-in-nepal
#
# 2. स्कटल्यान्डले नेपाललाई दियो १४१ रनको लक्ष्य
#    🔗 https://www.onlinekhabar.com/2026/01/1857271/scotland-sets-nepal-a-target-of-141-runs
#
# 3. लैंगिक विभेदविरुद्ध उभिएकी रखाल अब राष्ट्रिय सभामा
#    🔗 https://www.onlinekhabar.com/2026/01/1857258/womens-rights-activist-rakhal-now-in-the-national-assembly
#
# 4. नयाँ प्रतिनिधिसभामा हुने छैनन् अस्तिका दुई तिहाइ सांसद
#    🔗 https://www.onlinekhabar.com/2026/01/1856903/two-thirds-of-the-previous-mps-will-not-be-in-the-new-house-of-representatives
#
# 5. युद्धमा खुट्टा गुमाएकी गोमा आमाको मिर्गौला पाएर बाँच्न संघर्षरत श्रीमानसँग अस्पतालमा
#    🔗 https://www.onlinekhabar.com/2026/01/1857206/goma-who-lost-her-leg-in-the-war-is-in-the-hospital-with-her-husband-who-is-struggling-to-survive-after-receiving-a-kidney-from-her-mother
#
# 6. कस्तो छ तपाईंको ओछ्यान ?
#    🔗 https://www.onlinekhabar.com/web-stories/how-is-your-bed-the-importance-of-sleep-and-the-science-of-beds
#
# 7. के क्याल्सियम खाँदैमा हड्डी बलियो हुन्छ ?
#    🔗 https://www.onlinekhabar.com/web-stories/does-eating-calcium-make-bones-stronger
#
# 8. ७ तरिका, जसले बचत गर्न सिकाउँछ
#    🔗 https://www.onlinekhabar.com/web-stories/7-ways-that-teach-you-to-save
#
# 9. नाइट क्लबमा हुडीको टोपी लगाएर जान किन मिल्दैन ?
#    🔗 https://www.onlinekhabar.com/web-stories/why-cant-you-wear-a-hoodie-and-hat-to-a-nightclub
#
# 10. जाडोमा कसरी रहने स्वस्थ ? यी हुन् प्राकृतिक उपाय
#    🔗 https://www.onlinekhabar.com/web-stories/how-to-stay-healthy-in-winter-these-are-the-natural-remedies
